# %% [markdown]
# # Group 2 Assignment 1

# %%
# Import all the libraries, numpy and pandas for processing, and seaborn and matplotlib for visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
import sklearn.metrics as metrics
import math
import scipy.stats as stats
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor


# Ignore FutureWarnings
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
# Load the dataframe in
df = pd.read_csv('Ass1Data/California_Houses.csv')
df.head()
# Out:
#    Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  \
# 0            452600.0         8.3252          41        880           129
# 1            358500.0         8.3014          21       7099          1106
# 2            352100.0         7.2574          52       1467           190
# 3            341300.0         5.6431          52       1274           235
# 4            342200.0         3.8462          52       1627           280
#
#    Population  Households  Latitude  Longitude  Distance_to_coast  \
# 0         322         126     37.88    -122.23        9263.040773
# 1        2401        1138     37.86    -122.22       10225.733072
# 2         496         177     37.85    -122.24        8259.085109
# 3         558         219     37.85    -122.25        7768.086571
# 4         565         259     37.85    -122.25        7768.086571
#
#    Distance_to_LA  Distance_to_SanDiego  Distance_to_SanJose  \
# 0   556529.158342         735501.806984         67432.517001
# 1   554279.850069         733236.884360         65049.908574
# 2   554610.717069         733525.682937         64867.289833
# 3   555194.266086         734095.290744         65287.138412
# 4   555194.266086         734095.290744         65287.138412
#
#    Distance_to_SanFrancisco
# 0              21250.213767
# 1              20880.600400
# 2              18811.487450
# 3              18031.047568
# 4              18031.047568

# %% [markdown]
# ## EDA

# %%
# First, let's see a summary for all the columns
df.describe()
# Out:
#        Median_House_Value  Median_Income    Median_Age     Tot_Rooms  \
# count        20640.000000   20640.000000  20640.000000  20640.000000
# mean        206855.816909       3.870671     28.639486   2635.763081
# std         115395.615874       1.899822     12.585558   2181.615252
# min          14999.000000       0.499900      1.000000      2.000000
# 25%         119600.000000       2.563400     18.000000   1447.750000
# 50%         179700.000000       3.534800     29.000000   2127.000000
# 75%         264725.000000       4.743250     37.000000   3148.000000
# max         500001.000000      15.000100     52.000000  39320.000000
#
#        Tot_Bedrooms    Population    Households      Latitude     Longitude  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean     537.898014   1425.476744    499.539680     35.631861   -119.569704
# std      421.247906   1132.462122    382.329753      2.135952      2.003532
# min        1.000000      3.000000      1.000000     32.540000   -124.350000
# 25%      295.000000    787.000000    280.000000     33.930000   -121.800000
# 50%      435.000000   1166.000000    409.000000     34.260000   -118.490000
# 75%      647.000000   1725.000000    605.000000     37.710000   -118.010000
# max     6445.000000  35682.000000   6082.000000     41.950000   -114.310000
#
#        Distance_to_coast  Distance_to_LA  Distance_to_SanDiego  \
# count       20640.000000    2.064000e+04          2.064000e+04
# mean        40509.264883    2.694220e+05          3.981649e+05
# std         49140.039160    2.477324e+05          2.894006e+05
# min           120.676447    4.205891e+02          4.849180e+02
# 25%          9079.756762    3.211125e+04          1.594264e+05
# 50%         20522.019101    1.736675e+05          2.147398e+05
# 75%         49830.414479    5.271562e+05          7.057954e+05
# max        333804.686371    1.018260e+06          1.196919e+06
#
#        Distance_to_SanJose  Distance_to_SanFrancisco
# count         20640.000000              20640.000000
# mean         349187.551219             386688.422291
# std          217149.875026             250122.192316
# min             569.448118                456.141313
# 25%          113119.928682             117395.477505
# 50%          459758.877000             526546.661701
# 75%          516946.490963             584552.007907
# max          836762.678210             903627.663298

# %%
# And let's check with how many rows and columns we are working with -> 20.640 rows and 14 columns
df.shape
# Out:
# (20640, 14)

# %%
# Then, let's check the data summary, check for null-values, and check the data-types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Median_House_Value        20640 non-null  float64
#  1   Median_Income             20640 non-null  float64
#  2   Median_Age                20640 non-null  int64
#  3   Tot_Rooms                 20640 non-null  int64
#  4   Tot_Bedrooms              20640 non-null  int64
#  5   Population                20640 non-null  int64
#  6   Households                20640 non-null  int64
#  7   Latitude                  20640 non-null  float64
#  8   Longitude                 20640 non-null  float64
#  9   Distance_to_coast         20640 non-null  float64
#  10  Distance_to_LA            20640 non-null  float64
#  11  Distance_to_SanDiego      20640 non-null  float64
#  12  Distance_to_SanJose       20640 non-null  float64
#  13  Distance_to_SanFrancisco  20640 non-null  float64
# dtypes: float64(9), int64(5)
# memory usage: 2.2 MB

# %%
# We can double-check the null-values using
df.isnull().sum()
# Out:
# Median_House_Value          0
# Median_Income               0
# Median_Age                  0
# Tot_Rooms                   0
# Tot_Bedrooms                0
# Population                  0
# Households                  0
# Latitude                    0
# Longitude                   0
# Distance_to_coast           0
# Distance_to_LA              0
# Distance_to_SanDiego        0
# Distance_to_SanJose         0
# Distance_to_SanFrancisco    0
# dtype: int64

# %% [markdown]
# As can be seen, there are 20.640 entries of houses, and none of the columns contain null-values. That means that most of the data is quite clean already, as we don't need to process missing values or null values.

# %%
# Now, let's check the duplicate values for each column
df.nunique()
# Out:
# Median_House_Value           3842
# Median_Income               12928
# Median_Age                     52
# Tot_Rooms                    5926
# Tot_Bedrooms                 1928
# Population                   3888
# Households                   1815
# Latitude                      862
# Longitude                     844
# Distance_to_coast           12590
# Distance_to_LA              12590
# Distance_to_SanDiego        12590
# Distance_to_SanJose         12590
# Distance_to_SanFrancisco    12590
# dtype: int64

# %%
# Now let's check the correlation matrix for the dataset
corr_all_variables = df.corr()
corr_all_variables.style.format(precision=2).background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_42c16_row0_col0, #T_42c16_row1_col1, #T_42c16_row2_col2, #T_42c16_row3_col3, #T_42c16_row4_col4, #T_42c16_row5_col5, #T_42c16_row6_col6, #T_42c16_row7_col7, #T_42c16_row8_col8, #T_42c16_row9_col9, #T_42c16_row10_col10, #T_42c16_row11_col11, #T_42c16_row12_col12, #T_42c16_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_42c16_row0_col1 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_42c16_row0_col2 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_42c16_row0_col3, #T_42c16_row6_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_42c16_row0_col4 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_42c16_row0_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_42c16_row0_col6 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_42c16_row0_col7, #T_42c16_row0_col10 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_42c16_row0_col8, #T_42c16_row0_col13, #T_42c16_row11_col9 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_42c16_row0_col9, #T_42c16_row2_col3, #T_42c16_row2_col4, #T_42c16_row2_col5, #T_42c16_row2_col6, #T_42c16_row3_col2, #T_42c16_row8_col7, #T_42c16_row8_col10, #T_42c16_row8_col11, #T_42c16_row9_col0, #T_42c16_row9_col1, #T_42c16_row11_col8, #T_42c16_row11_col12, #T_42c16_row11_col13 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_42c16_row0_col11, #T_42c16_row4_col10, #T_42c16_row6_col7 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_42c16_row0_col12, #T_42c16_row4_col7, #T_42c16_row9_col13 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_42c16_row1_col0 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_42c16_row1_col2, #T_42c16_row7_col6, #T_42c16_row11_col6, #T_42c16_row13_col1 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_42c16_row1_col3, #T_42c16_row3_col0, #T_42c16_row5_col10 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_42c16_row1_col4, #T_42c16_row11_col3 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_42c16_row1_col5, #T_42c16_row10_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_42c16_row1_col6, #T_42c16_row10_col2 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_42c16_row1_col7, #T_42c16_row6_col10 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_42c16_row1_col8 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_42c16_row1_col9 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_42c16_row1_col10, #T_42c16_row2_col8 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_42c16_row1_col11, #T_42c16_row3_col7, #T_42c16_row3_col10 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_42c16_row1_col12 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_42c16_row1_col13, #T_42c16_row3_col11 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_42c16_row2_col0 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_42c16_row2_col1, #T_42c16_row9_col2 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_42c16_row2_col7, #T_42c16_row3_col12 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_42c16_row2_col9, #T_42c16_row12_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_42c16_row2_col10, #T_42c16_row4_col11, #T_42c16_row6_col11, #T_42c16_row10_col9 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_42c16_row2_col11, #T_42c16_row6_col13 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_42c16_row2_col12, #T_42c16_row5_col7 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_42c16_row2_col13, #T_42c16_row9_col12 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_42c16_row3_col1, #T_42c16_row4_col0 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_42c16_row3_col4, #T_42c16_row4_col3 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_42c16_row3_col5 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_42c16_row3_col6 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_42c16_row3_col8, #T_42c16_row4_col13, #T_42c16_row5_col12 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_42c16_row3_col9 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_42c16_row3_col13 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_42c16_row4_col1, #T_42c16_row13_col2 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_42c16_row4_col2 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_42c16_row4_col5 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_42c16_row4_col6, #T_42c16_row6_col4 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_42c16_row4_col8, #T_42c16_row5_col13, #T_42c16_row7_col9 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_42c16_row4_col9, #T_42c16_row5_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_42c16_row4_col12 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_42c16_row5_col1, #T_42c16_row10_col4, #T_42c16_row12_col2 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_42c16_row5_col2, #T_42c16_row10_col12 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_42c16_row5_col3 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_42c16_row5_col4 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_42c16_row5_col6, #T_42c16_row6_col5 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_42c16_row5_col8 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_42c16_row5_col9, #T_42c16_row11_col2, #T_42c16_row12_col0, #T_42c16_row12_col5, #T_42c16_row13_col3 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_42c16_row5_col11 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_42c16_row6_col1 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_42c16_row6_col2, #T_42c16_row10_col13 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_42c16_row6_col3 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_42c16_row6_col8 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_42c16_row6_col9, #T_42c16_row7_col2, #T_42c16_row8_col6 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_42c16_row6_col12, #T_42c16_row9_col8 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_42c16_row7_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_42c16_row7_col1 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_42c16_row7_col3 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_42c16_row7_col4, #T_42c16_row11_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_42c16_row7_col5 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_42c16_row7_col8, #T_42c16_row7_col12, #T_42c16_row7_col13 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_42c16_row7_col10, #T_42c16_row10_col7 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_42c16_row7_col11, #T_42c16_row11_col7, #T_42c16_row12_col13, #T_42c16_row13_col12 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_42c16_row8_col0, #T_42c16_row12_col3, #T_42c16_row12_col4, #T_42c16_row13_col4 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_42c16_row8_col1 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_42c16_row8_col2, #T_42c16_row9_col6, #T_42c16_row10_col6 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_42c16_row8_col3, #T_42c16_row13_col0, #T_42c16_row13_col5 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_42c16_row8_col4 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_42c16_row8_col5 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_42c16_row8_col9 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_42c16_row8_col12 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_42c16_row8_col13, #T_42c16_row13_col8 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_42c16_row9_col3 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_42c16_row9_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_42c16_row9_col5 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_42c16_row9_col7 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_42c16_row9_col10 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_42c16_row9_col11 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_42c16_row10_col1, #T_42c16_row10_col5, #T_42c16_row11_col5 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_42c16_row10_col3 {
#   background-color: #8db0fe;
#   colo

# %% [markdown]
# Since our target variable is 'median_house_value', and our interest is in whether the proximity to an urban center has influence on it, we'll focus further now on the variables: 'Median_House_Value' and 'Distance_to_coast', 'Distance_to_LA', 'Distance_to_SanDiego', 'Distance_to_SanJose', 'Distance_to_SanFrancisco'

# %%
# Let's see the correlation matrix for only the distance columns again
distance_columns = df[['Median_House_Value', 'Distance_to_coast', 'Distance_to_LA', 'Distance_to_SanDiego', 'Distance_to_SanJose', 'Distance_to_SanFrancisco']]
corr_distances = distance_columns.corr()

# Plot the heatmap and save it as an image
plt.figure(figsize=(10, 8))
sns.heatmap(corr_distances, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix for Distance Columns')
plt.savefig('corr_distances.png')
plt.show()

# %%
# Plot histograms for all distance columns in a matrix of subplots
fig, axes = plt.subplots(3, 2, figsize=(10, 10))
fig.suptitle('Distribution of Median House Value and Distance to Cities and Coast', fontsize=16)

# Plot each column
for ax, column in zip(axes.flatten(), distance_columns):
    sns.histplot(data=distance_columns, x=column, bins=30, kde=True, ax=ax)
    ax.set_title(f'Distribution of {column}')
    ax.set_ylabel('Number of houses')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# From the density plot of the Median House Value, there is a skewness to the left. However, there is a noticeable increase on the highest end of Median_House_Value, so that needs to be expected more closely!

# %%
# Display the table for the histogram of 'Median_House_Value'
median_house_value_counts = df['Median_House_Value'].value_counts().sort_index()
print(median_house_value_counts)
# Out:
# Median_House_Value
# 14999.0       4
# 17500.0       1
# 22500.0       4
# 25000.0       1
# 26600.0       1
#            ...
# 498800.0      1
# 499000.0      1
# 499100.0      1
# 500000.0     27
# 500001.0    965
# Name: count, Length: 3842, dtype: int64

# %% [markdown]
# From the table, it can be seen that there are 965 entries of houses with a median house value of 500001.0. A reason for this could be that this is the limit of median income, and therefore the cut-off value for median_house_value.

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Splitting the data in test and training data

# %%
#  Select the variables that we want as outcome (y) amd prediciton (x) variables
X = df[['Distance_to_LA', 'Distance_to_SanDiego', 'Distance_to_SanJose', 'Distance_to_SanFrancisco', 'Distance_to_coast']]
y = df[['Median_House_Value']]

# Split the data with 75% train and 25% test.
x_train, x_test, y_train, y_test = train_test_split(X, y, random_state=6666)

# %% [markdown]
# ### Polynomial Linear Regression attempt

# %%
mod_poly = LinearRegression()
mod_poly.fit(x_train, y_train)

y_lin_pred = mod_poly.predict(x_test)
y_lin_pred
# Out:
# array([[145463.34204337],
#        [249788.2688035 ],
#        [180305.09418254],
#        ...,
#        [192251.96697335],
#        [256907.51539726],
#        [173048.53912126]])

# %%
# Calculate the residuals
residuals = y_test.values.flatten() - y_lin_pred.flatten()

# Q-Q plot of residuals
plt.figure(figsize=(8, 6))
stats.probplot(residuals, dist="norm", plot=plt)
plt.title('Q-Q Plot of Residuals for linear regression')
plt.show()

# %%
# Define the predictor columns
predictors = ['Distance_to_LA', 'Distance_to_SanDiego', 'Distance_to_SanJose', 'Distance_to_SanFrancisco', 'Distance_to_coast']

# Set up the plot
plt.figure(figsize=(15, 10))

# Create a scatter plot for each predictor
for i, predictor in enumerate(predictors, 1):
    plt.subplot(3, 2, i)  # Create a 3x2 grid of plots
    sns.scatterplot(x=x_train[predictor], y=y_train['Median_House_Value'])
    plt.title(f'{predictor} vs Median_House_Value')
    plt.xlabel(predictor)
    plt.ylabel('Median House Value')
    
    # Add a trend line 
    sns.regplot(x=x_train[predictor], y=y_train['Median_House_Value'], scatter=False, color='red')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Decision Tree Regression

# %%
# Create the decision tree regressor
decision_tree_model = DecisionTreeRegressor(random_state=6666)

# Train the model
decision_tree_model.fit(x_train, y_train)

# Make predictions
y_dec_pred = decision_tree_model.predict(x_test)

# %%
# Calculate the evaluation metrics for decision trees
MSE_dec = metrics.mean_squared_error(y_test, y_dec_pred)
RMSE_dec = math.sqrt(MSE_dec)
MAE_dec = metrics.mean_absolute_error(y_test, y_dec_pred)
R2_dec = metrics.r2_score(y_test, y_dec_pred)
Med_abs_er_dec = metrics.median_absolute_error(y_test, y_dec_pred)

print(MSE_dec, RMSE_dec, MAE_dec, R2_dec, Med_abs_er_dec)
# Out:
# 4456259893.707648 66755.22371850497 40611.262679109765 0.6653262525825225 21400.0

# %%
# Plot the histograms for decision trees
sns.histplot(y_test, label='Actual Values')
sns.histplot(y_dec_pred, label='Predicted Values')
plt.legend()

# %%
print(decision_tree_model.score(X, y))
# Out:
# 0.8822108763269831

# %% [markdown]
# ### K neighbors Regressor

# %%
# Define the parameter grid for n_neighbors
param_grid = {'n_neighbors': range(1, 21)}

# Initialize the KNeighborsRegressor
knn = KNeighborsRegressor()

# Use GridSearchCV to search for the best value of n_neighbors
grid_search = GridSearchCV(knn, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fit the model
grid_search.fit(x_train, y_train)

best_n_neighbors = grid_search.best_params_['n_neighbors']
best_n_neighbors
# Out:
# 6

# %%
# Initialise model with recommended n
knn_model = KNeighborsRegressor(n_neighbors=6)

# Fit the model
knn_model.fit(x_train, y_train)

# Predict test values
y_knn_pred = knn_model.predict(x_test)

# %%
# Visualising the predicted and actual values of the KNN
sns.histplot(y_test, label='Actual Values')
sns.histplot(y_knn_pred, label='Predicted Values', color='orange')
plt.legend()

# %%
# Calculate the evaluation metrics for KNN
MSE_knn = metrics.mean_squared_error(y_test, y_knn_pred)
RMSE_knn = math.sqrt(MSE_knn)
MAE_knn = metrics.mean_absolute_error(y_test, y_knn_pred)
R2_knn = metrics.r2_score(y_test, y_knn_pred)
Med_abs_er_knn = metrics.median_absolute_error(y_test, y_knn_pred)

print(MSE_knn, RMSE_knn, MAE_knn, R2_knn, Med_abs_er_knn)
# Out:
# 3186516489.716543 56449.23816772502 36495.735949612405 0.7606864410383994 21050.000000000007

# %% [markdown]
# ## Evaluation

# %%
# Calculate the knn bias
bias_knn = np.mean((y_test - y_knn_pred) ** 2)
# Calculate the knn variance
variance_knn = np.var(y_knn_pred)

# %%
# Calculate the total variance of the target variable
total_variance = np.var(y_test)

# %%
# Calculate the variance explained by the linear regression model
explained_variance_knn = R2_knn * total_variance

# Calculate the irreducible error for the linear regression model
irreducible_error_knn = total_variance - explained_variance_knn
irreducible_error_knn
# Out:
# Median_House_Value    3.186516e+09
# dtype: float64

# %%
# Calculate the decision tree bias
bias_dec = np.mean((y_test.values.flatten() - y_dec_pred) ** 2)
# Calculate the decision tree variance
variance_dec = np.var(y_dec_pred)

# %%
# Calculate the variance explained by the decision tree model
explained_variance_dec = R2_dec * total_variance

# Calculate the irreducible error for the decision tree model
irreducible_error_dec = total_variance - explained_variance_dec
irreducible_error_dec
# Out:
# Median_House_Value    4.456260e+09
# dtype: float64

# %%
# Create a dictionary with the results
results = {
    'Model': ['KNN', 'Decision Tree'],
    'MSE': [MSE_knn, MSE_dec],
    'RMSE': [RMSE_knn, RMSE_dec],
    'MAE': [MAE_knn, MAE_dec],
    'R2': [R2_knn, R2_dec],
    'Med_abs_er': [Med_abs_er_knn, Med_abs_er_dec],
    'Bias2': [bias_knn, bias_dec],
    'Variance': [variance_knn, variance_dec],
    'Irreducible Error': [irreducible_error_knn.values[0], irreducible_error_dec.values[0]]
}

# %%
# Create the dataframe
results_df = pd.DataFrame(results)

# Display the dataframe
results_df.set_index('Model').T
# Out:
# Model                       KNN  Decision Tree
# MSE                3.186516e+09   4.456260e+09
# RMSE               5.644924e+04   6.675522e+04
# MAE                3.649574e+04   4.061126e+04
# R2                 7.606864e-01   6.653263e-01
# Med_abs_er         2.105000e+04   2.140000e+04
# Bias2              3.186516e+09   4.456260e+09
# Variance           1.002153e+10   1.242893e+10
# Irreducible Error  3.186516e+09   4.456260e+09

# %%
results_melted = results_df.melt(id_vars='Model', var_name='Metric', value_name='Value')

# Split the metrics into two categories: positive and negative
large_metrics = results_melted[results_melted['Value'] >= 1e+05]
medium_metrics = results_melted[(results_melted['Value'] >= 1e+04) & (results_melted['Value'] < 1e+05)]
small_metrics = results_melted[results_melted['Value'] < 1e+04]

# %%
# visualise the large evaluation metrics
sns.barplot(data=large_metrics, x='Model', y='Value', hue='Metric')
plt.title('Comparison of Large Metrics for KNN and Decision Tree Models')
plt.xticks(rotation=45)
plt.legend(loc='upper center')

plt.show()

# %%
# visualise the medium evaluation metrics

sns.barplot(data=medium_metrics, x='Model', y='Value', hue='Metric')
plt.title('Comparison of Medium Metrics for KNN and Decision Tree Models')
plt.xticks(rotation=45)
plt.legend(loc=0)

plt.show()

# %%
# visualise the small evaluation metrics

sns.barplot(data=small_metrics, x='Model', y='Value', hue='Metric')
plt.title('Comparison of Small Metrics for KNN and Decision Tree Models')
plt.xticks(rotation=45)
plt.legend(loc='upper left')

plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

# Plot for Linear Regression
sns.histplot(y_test, label='Actual Values', ax=axes[0], color='blue')
sns.histplot(y_knn_pred.flatten(), label='Predicted Values', ax=axes[0], color='orange')
axes[0].set_title('KNN regression on median house prices on proximity to a big city / urban center', size=10)
axes[0].legend()

# Plot for Decision Tree
sns.histplot(y_test, label='Actual Values', ax=axes[1], color='blue')
sns.histplot(y_dec_pred, label='Predicted Values', ax=axes[1], color='orange')
axes[1].set_title('Decision Tree regression on median house prices on proximity to a big city / urban center', size=10)
axes[1].legend()
axes[0].set_ylabel('Median House Income')
plt.tight_layout()
plt.show()
